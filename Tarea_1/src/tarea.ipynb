# %%
import pandas as pd

# %%
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score

# %%
from matplotlib import pyplot

# %%
DATASET_PATH = "../data/diabetes.csv"
diab = pd.read_csv(DATASET_PATH)

datos = diab.drop(columns=["Outcome"])
etiquetas = diab["Outcome"]

# %%
x_train, x_test, y_train, y_test = train_test_split(datos, etiquetas, test_size=0.8)
model_tree = tree.DecisionTreeClassifier()
model_tree = model_tree.fit(x_train, y_train)

# %%
y_pred = model_tree.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Precisión del modelo: {accuracy * 100:.2f}%")
# Out:
# Precisión del modelo: 66.18%

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["No Diabetes", "Diabetes"])
disp.plot()   
pyplot.show()

# %% [markdown]
# • ¿Que se concluye de la matriz de confusion?, explique el resultado.
#
# Con un 20% de datos para testear, se obtuvo un rango de precision de 65 a 75 por ciento. Sin embargo se bio que varios parametros se encuentran con valores 0 donde no deberia, o arrojan valores muy altos, por lo que el dataset deberia mejorarse y llevar una documentacion para saber las medidas de mis parametros y teer mas informacion. hay una gran parte que arroja resultados erroneos y podria afinarse un poco, pero con diferente conjunto de datos podria mejorar mas el resultado.
#
# • Utilizando el conjunto de test. ¿Cual porcentaje del Dataset obtiene mejores resultados? ¿Son ´
# confiables los resultados?
#
# con 10% o 30% de datos para testear, se obtienen rango de resultados de 60 a 75 por ciento de precision, incluso hasta 80% de presicion. Si reservo arriba del 60% de datos para testear, los valores de presicion no suelen subir del 70 por ciento de precision, por lo cual no son valores acpetables para el entrenamiento de la maquina.
#
# Creo que el rango de Presicion mas confiable es de 10% a 30% de datos para el test, asi no genero falsos positivos y falsos negativos
